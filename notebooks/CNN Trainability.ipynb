# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt

# %%
import os
os.environ['HOME_DIR'] = 'drive/MyDrive/hidden-networks'
# !pip install -r $HOME_DIR/requirements.txt

import sys
sys.path.append(os.path.join('/content', os.environ['HOME_DIR']))

# %%
plt.plot(baseline_prune_acc)

# %%
import seaborn as sns
sns.set_theme()
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 300

# %%
plt.errorbar(np.arange(0, 150, 1), total_ortho_mean, yerr = 1.96 * total_ortho_sd, linewidth=1, elinewidth=0.5)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
print(total_baseline_mean[-1])
print(total_baseline_sd[-1])
# Out:
# 81.39333333333333
# 0.1649915822768651

# %%
print(total_ortho_mean[-1])
print(total_ortho_sd[-1])
# Out:
# 81.87666666666667
# 0.13274871834493454

# %%
plt.ylim(70, 83)
plt.xticks(np.arange(0, 150+1, 25.0))
plt.errorbar(np.arange(1, 151, 1), total_ortho_mean, yerr = total_ortho_sd, linewidth=1, elinewidth=0.25, label="Orthogonal Regularization")
plt.errorbar(np.arange(1, 151, 1), total_baseline_mean, yerr = total_baseline_sd, linewidth=1, elinewidth=0.25, label="Baseline")
plt.legend(loc="upper left", prop={'size': 9})
plt.axvline(x=100, color='r', linewidth=0.5,linestyle="--")
plt.xlabel("Training Epoch")
plt.ylabel("Test Accuracy")
plt.text(40, 70.5, 'Pruning Phase', fontsize = 8, color="darkred", fontstyle="italic", bbox=dict(facecolor='white', alpha=0.75))
plt.text(110, 70.5, 'Training Phase', fontsize = 8, color="darkred", fontstyle="italic", bbox=dict(facecolor='white', alpha=0.75))
plt.savefig("/content/drive/MyDrive/hidden-networks/jeffrey_data/comparison.png", dpi=1200)

# %%
total_baseline = np.stack((np.concatenate([baseline_prune_acc, baseline_train_acc]), np.concatenate([baseline_prune_acc2, baseline_train_acc2]), np.concatenate([baseline_prune_acc3, baseline_train_acc3])))
total_baseline_mean = np.mean(total_baseline, axis=0)
total_baseline_sd = np.std(total_baseline, axis=0)

np.savetxt("/content/drive/MyDrive/hidden-networks/jeffrey_data/total_baseline.csv", total_baseline, delimiter=",")
np.savetxt("/content/drive/MyDrive/hidden-networks/jeffrey_data/total_baseline_mean.csv", total_baseline_mean, delimiter=",")
np.savetxt("/content/drive/MyDrive/hidden-networks/jeffrey_data/total_baseline_sd.csv", total_baseline_sd, delimiter=",")

# %%
total_ortho = np.stack((np.concatenate([ortho_prune_acc, ortho_train_acc]), np.concatenate([ortho2_prune_acc, ortho2_train_acc]), np.concatenate([ortho3_prune_acc, ortho3_train_acc])))
total_ortho_mean = np.mean(total_ortho, axis=0)
total_ortho_sd = np.std(total_ortho, axis=0)

np.savetxt("/content/drive/MyDrive/hidden-networks/jeffrey_data/total_ortho.csv", total_ortho, delimiter=",")
np.savetxt("/content/drive/MyDrive/hidden-networks/jeffrey_data/total_ortho_mean.csv", total_ortho_mean, delimiter=",")
np.savetxt("/content/drive/MyDrive/hidden-networks/jeffrey_data/total_ortho_sd.csv", total_ortho_sd, delimiter=",")

# %%
plt.ylim(70, 83)
plt.xticks(np.arange(0, 150+1, 25.0))
plt.plot(np.concatenate([ortho3_prune_acc, ortho3_train_acc]), label="Orthogonal Regularization", linewidth=1)
plt.plot(np.concatenate([baseline_prune_acc3, baseline_train_acc3]), label="Baseline", linewidth=1)
plt.legend(loc="upper left", prop={'size': 9})
plt.axvline(x=100, color='r', linewidth=0.5,linestyle="--")
plt.xlabel("Training Epoch")
plt.ylabel("Test Accuracy")
plt.text(40, 70.5, 'Pruning Phase', fontsize = 8, color="darkred", fontstyle="italic", bbox=dict(facecolor='white', alpha=0.75))
plt.text(110, 70.5, 'Training Phase', fontsize = 8, color="darkred", fontstyle="italic", bbox=dict(facecolor='white', alpha=0.75))
#plt.savefig("/content/drive/MyDrive/hidden-networks/jeffrey_data/accuracy.png", dpi=600)
# Out:
# Text(110, 70.5, 'Training Phase')

# %%
prune_loss
# Out:
# array([0.00146181, 0.00129533, 0.00114883, 0.0011221 , 0.00106086,
#        0.00099354, 0.00096793, 0.00089919, 0.00092641, 0.00088317,
#        0.00088731, 0.00081936, 0.00085713, 0.0008147 , 0.00083679,
#        0.00081698, 0.00081916, 0.00081941, 0.00077982, 0.00078558,
#        0.00078495, 0.00078424, 0.00075103, 0.00076058, 0.00079828,
#        0.00075121, 0.00076824, 0.00076951, 0.00072695, 0.00077331,
#        0.00073212, 0.00077634, 0.00072292, 0.00074359, 0.00077288,
#        0.00076493, 0.00074774, 0.00074217, 0.00075175, 0.00072318,
#        0.00074561, 0.00074525, 0.00076137, 0.00071384, 0.00072201,
#        0.00070048, 0.00069539, 0.00071812, 0.00072428, 0.00069571,
#        0.00069748, 0.00070236, 0.00069561, 0.00072542, 0.00068824,
#        0.00068466, 0.0006826 , 0.00067678, 0.00065364, 0.00066102,
#        0.00066451, 0.0006822 , 0.00067027, 0.0006529 , 0.00064204,
#        0.00065195, 0.00064392, 0.00067332, 0.00064825, 0.00062161,
# ...

# %%
plt.ylim(70, 83)
plt.xticks(np.arange(0, 150+1, 25.0))
plt.plot(np.concatenate([ortho2_prune_acc, ortho2_train_acc]), label="Orthogonal Regularization", linewidth=1)
plt.plot(np.concatenate([baseline_prune_acc2, baseline_train_acc2]), label="Baseline", linewidth=1)
plt.legend(loc="upper left", prop={'size': 9})
plt.axvline(x=100, color='r', linewidth=0.5,linestyle="--")
plt.xlabel("Training Epoch")
plt.ylabel("Test Accuracy")
plt.text(40, 70.5, 'Pruning Phase', fontsize = 8, color="darkred", fontstyle="italic", bbox=dict(facecolor='white', alpha=0.75))
plt.text(110, 70.5, 'Training Phase', fontsize = 8, color="darkred", fontstyle="italic", bbox=dict(facecolor='white', alpha=0.75))
#plt.savefig("/content/drive/MyDrive/hidden-networks/jeffrey_data/accuracy.png", dpi=600)
# Out:
# Text(110, 70.5, 'Training Phase')

# %%
plt.ylim(70, 83)
plt.xticks(np.arange(0, 150+1, 25.0))
plt.plot(np.concatenate([ortho_prune_acc, ortho_train_acc]), label="Orthogonal Regularization", linewidth=1)
plt.plot(np.concatenate([baseline_prune_acc, baseline_train_acc]), label="Baseline", linewidth=1)
plt.legend(loc="upper left", prop={'size': 9})
plt.axvline(x=100, color='r', linewidth=0.5,linestyle="--")
plt.xlabel("Training Epoch")
plt.ylabel("Test Accuracy")
plt.text(40, 70.5, 'Pruning Phase', fontsize = 8, color="darkred", fontstyle="italic", bbox=dict(facecolor='white', alpha=0.75))
plt.text(110, 70.5, 'Training Phase', fontsize = 8, color="darkred", fontstyle="italic", bbox=dict(facecolor='white', alpha=0.75))
plt.savefig("/content/drive/MyDrive/hidden-networks/jeffrey_data/accuracy.png", dpi=600)

# %%
baseline_prune_acc = np.loadtxt("/content/drive/MyDrive/hidden-networks/jeffrey_data/baseline_fat_100_50_prune_acc.csv")
baseline_prune_loss = np.loadtxt("/content/drive/MyDrive/hidden-networks/jeffrey_data/baseline_fat_100_50_prune_loss.csv")
baseline_train_acc = np.loadtxt("/content/drive/MyDrive/hidden-networks/jeffrey_data/baseline_fat_100_50_train_acc.csv")
baseline_train_loss = np.loadtxt("/content/drive/MyDrive/hidden-networks/jeffrey_data/baseline_fat_100_50_train_loss.csv")

baseline_prune_acc2 = np.loadtxt("/content/drive/MyDrive/hidden-networks/jeffrey_data/baseline_fat_200_prune_acc4.csv")
baseline_prune_loss2 = np.loadtxt("/content/drive/MyDrive/hidden-networks/jeffrey_data/baseline_fat_200_prune_loss4.csv")
baseline_train_acc2 = np.loadtxt("/content/drive/MyDrive/hidden-networks/jeffrey_data/baseline_fat_200_train_acc4.csv")
baseline_train_loss2 = np.loadtxt("/content/drive/MyDrive/hidden-networks/jeffrey_data/baseline_fat_200_train_loss4.csv")

baseline_prune_acc3 = np.loadtxt("/content/drive/MyDrive/hidden-networks/jeffrey_data/1e-5_3_prune_acc.csv")
baseline_prune_loss3 = np.loadtxt("/content/drive/MyDrive/hidden-networks/jeffrey_data/1e-5_3_prune_loss.csv")
baseline_train_acc3 = np.loadtxt("/content/drive/MyDrive/hidden-networks/jeffrey_data/1e-5_3_train_acc.csv")
baseline_train_loss3 = np.loadtxt("/content/drive/MyDrive/hidden-networks/jeffrey_data/1e-5_3_train_loss.csv")

# %%
ortho_prune_acc = np.loadtxt("/content/drive/MyDrive/hidden-networks/jeffrey_data/1e-5_100_50_prune_acc.csv")
ortho2_prune_acc = np.loadtxt("/content/drive/MyDrive/hidden-networks/jeffrey_data/1e-5_2_prune_acc.csv")
ortho3_prune_acc = np.loadtxt("/content/drive/MyDrive/hidden-networks/jeffrey_data/1e-5_4_prune_acc.csv")

ortho_prune_loss = np.loadtxt("/content/drive/MyDrive/hidden-networks/jeffrey_data/1e-5_100_50_prune_loss.csv")
ortho2_prune_loss = np.loadtxt("/content/drive/MyDrive/hidden-networks/jeffrey_data/1e-5_2_prune_loss.csv")
ortho3_prune_loss = np.loadtxt("/content/drive/MyDrive/hidden-networks/jeffrey_data/1e-5_4_prune_loss.csv")

ortho_train_acc = np.loadtxt("/content/drive/MyDrive/hidden-networks/jeffrey_data/1e-5_100_50_train_acc.csv")
ortho2_train_acc = np.loadtxt("/content/drive/MyDrive/hidden-networks/jeffrey_data/1e-5_2_train_acc.csv")
ortho3_train_acc = np.loadtxt("/content/drive/MyDrive/hidden-networks/jeffrey_data/1e-5_4_train_acc.csv")

ortho_train_loss = np.loadtxt("/content/drive/MyDrive/hidden-networks/jeffrey_data/1e-5_100_50_train_loss.csv")
ortho2_train_loss = np.loadtxt("/content/drive/MyDrive/hidden-networks/jeffrey_data/1e-5_2_train_loss.csv")
ortho3_train_loss = np.loadtxt("/content/drive/MyDrive/hidden-networks/jeffrey_data/1e-5_4_train_loss.csv")

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.optim.lr_scheduler import CosineAnnealingLR
import torch.autograd as autograd
import collections
import numpy as np
from scipy.integrate import quad, dblquad
from scipy.stats import hypsecant
from scipy.stats import uniform, norm
import math

# from signal_supermask_pruning2 import GetSubnet, SupermaskConv, SupermaskLinear
# from signal_supermask_pruning2 import train, test
from jeffrey_utils import *
from regularization import srip_reg, ortho_reg

# %%
np.savetxt("/content/drive/MyDrive/hidden-networks/jeffrey_data/testing.csv", prune_loss, delimiter=",")

# %%
num_layers = 2
sparsity = 0.5
layer_size = 7000

model_args = {
  "dataset": "CIFAR10",
  "batch_size": 128, # input batch size for training (default: 64)
  "epochs": 100, # number of epochs to train (default: 14)
  "lr": 0.1, # learning rate (default: 0.1)
  "momentum": 0.9, # Momentum (default: 0.9)
  'wd': 1e-4, # Weight decay (default: 0.0005)
  'no_cuda': False, # disables CUDA training
  'seed': 69, # random seed (default: 1)
  'save_name': None, # "simple20_rs2", # For Saving the current Model, None if not saving
  'sparsity': [sparsity] * 5, # 'how sparse is each layer'
  'copy_layers': [], # ['conv1', 'conv2', 'fc2'],
  'freeze_layers': [],
  'bias': False,
}

prune_args = {
    "test_batch_size": 1000, # input batch size for testing (default: 1000)
    'data': '../data', # Location to store data (e.g. MNIST)
    'log_interval': 100, # how many batches to wait before logging training status
    'train_eval_interval': None, # epoch interval at which to print training accuracy
    'test_eval_interval': 1, # epoch interval at which to print test accuracy
    'eval_train_on_last': False,
    'eval_test_on_last': True,
    'eval_on_last': True,
    'alpha': 0,
    'reg': 'orth'
}

train_args = {
  "lr": 1e-4, # learning rate (default: 0.1)
  "momentum": 0.9, # Momentum (default: 0.9)
  'wd': 1e-3, # Weight decay (default: 0.0005)
  'epochs': 50,
  'log_interval': 100, # how many batches to wait before logging training status
  'train_eval_interval': None, # epoch interval at which to print training accuracy
  'test_eval_interval': 1, # epoch interval at which to print test accuracy
  'eval_train_on_last': False,
  'eval_test_on_last': True,
  'alpha': 0,
  'reg':'srip'
}



trained_model2, pruned_model2, device, train_loader, test_loader, criterion, prune_acc, prune_loss, train_acc, train_loss = prune_and_train(model_args, prune_args, train_args, cnn=True)
np.savetxt("/content/drive/MyDrive/hidden-networks/jeffrey_data/baseline_fat_200_prune_loss4.csv", prune_loss, delimiter=",")
np.savetxt("/content/drive/MyDrive/hidden-networks/jeffrey_data/baseline_fat_200_prune_acc4.csv", prune_acc, delimiter=",")
np.savetxt("/content/drive/MyDrive/hidden-networks/jeffrey_data/baseline_fat_200_train_loss4.csv", train_loss, delimiter=",")
np.savetxt("/content/drive/MyDrive/hidden-networks/jeffrey_data/baseline_fat_200_train_acc4.csv", train_acc, delimiter=",")
torch.save(trained_model2.state_dict(), "/content/drive/MyDrive/hidden-networks/jeffrey_models/trained_baseline_fat_200_1004.pt")
torch.save(pruned_model2.state_dict(), "/content/drive/MyDrive/hidden-networks/jeffrey_models/pruned_baseline_fat_200_1004.pt")
# Out:
# Using device cuda
# ...
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting ../data/CIFAR10/cifar-10-python.tar.gz to ../data/CIFAR10
# Train Epoch: 1 [0/50000 (0%)]	Loss: 2.338900
# Train Epoch: 1 [12800/50000 (26%)]	Loss: 1.767143
# Train Epoch: 1 [25600/50000 (51%)]	Loss: 1.706764
# Train Epoch: 1 [38400/50000 (77%)]	Loss: 1.537814
#
# Test set: Average loss: 0.0015, Accuracy: 4699/10000 (47%)
#
# Train Epoch: 2 [0/50000 (0%)]	Loss: 1.468489
# Train Epoch: 2 [12800/50000 (26%)]	Loss: 1.318095
# Train Epoch: 2 [25600/50000 (51%)]	Loss: 1.476377
# Train Epoch: 2 [38400/50000 (77%)]	Loss: 1.474314
#
# Test set: Average loss: 0.0013, Accuracy: 5409/10000 (54%)
#
# Train Epoch: 3 [0/50000 (0%)]	Loss: 1.322545
# Train Epoch: 3 [12800/50000 (26%)]	Loss: 1.448610
# Train Epoch: 3 [25600/50000 (51%)]	Loss: 1.332905
# Train Epoch: 3 [38400/50000 (77%)]	Loss: 1.268691
#
# Test set: Average loss: 0.0011, Accuracy: 5939/10000 (59%)
#
# Train Epoch: 4 [0/50000 (0%)]	Loss: 1.286482
# ...

# %%
ortho_reg(pruned_model2.get_pruned_weights())
# Out:
# tensor(83.9737, device='cuda:0', grad_fn=<AddBackward0>)

# %%
num_layers = 2
sparsity = 0.5
layer_size = 7000

model_args = {
  "dataset": "CIFAR10",
  "batch_size": 128, # input batch size for training (default: 64)
  "epochs": 100, # number of epochs to train (default: 14)
  "lr": 0.1, # learning rate (default: 0.1)
  "momentum": 0.9, # Momentum (default: 0.9)
  'wd': 1e-4, # Weight decay (default: 0.0005)
  'no_cuda': False, # disables CUDA training
  'seed': 69, # random seed (default: 1)
  'save_name': None, # "simple20_rs2", # For Saving the current Model, None if not saving
  'sparsity': [sparsity] * 5, # 'how sparse is each layer'
  'copy_layers': [], # ['conv1', 'conv2', 'fc2'],
  'freeze_layers': [],
  'bias': False,
}

prune_args = {
    "test_batch_size": 1000, # input batch size for testing (default: 1000)
    'data': '../data', # Location to store data (e.g. MNIST)
    'log_interval': 100, # how many batches to wait before logging training status
    'train_eval_interval': None, # epoch interval at which to print training accuracy
    'test_eval_interval': 1, # epoch interval at which to print test accuracy
    'eval_train_on_last': False,
    'eval_test_on_last': True,
    'eval_on_last': True,
    'alpha': 1e-4,
    'reg': 'orth'
}

train_args = {
  "lr": 1e-4, # learning rate (default: 0.1)
  "momentum": 0.9, # Momentum (default: 0.9)
  'wd': 1e-3, # Weight decay (default: 0.0005)
  'epochs': 50,
  'log_interval': 100, # how many batches to wait before logging training status
  'train_eval_interval': None, # epoch interval at which to print training accuracy
  'test_eval_interval': 1, # epoch interval at which to print test accuracy
  'eval_train_on_last': False,
  'eval_test_on_last': True,
  'alpha': 0,
  'reg':'srip'
}



trained_model2, pruned_model2, device, train_loader, test_loader, criterion, prune_acc, prune_loss, train_acc, train_loss = prune_and_train(model_args, prune_args, train_args, cnn=True)
np.savetxt("/content/drive/MyDrive/hidden-networks/jeffrey_data/1e-4_100_50_prune_loss.csv", prune_loss, delimiter=",")
np.savetxt("/content/drive/MyDrive/hidden-networks/jeffrey_data/1e-4_100_50_prune_acc.csv", prune_acc, delimiter=",")
np.savetxt("/content/drive/MyDrive/hidden-networks/jeffrey_data/1e-4_100_50_train_loss.csv", train_loss, delimiter=",")
np.savetxt("/content/drive/MyDrive/hidden-networks/jeffrey_data/1e-4_100_50_train_acc.csv", train_acc, delimiter=",")
torch.save(trained_model2.state_dict(), "/content/drive/MyDrive/hidden-networks/jeffrey_models/1e-4_100_50.pt")
torch.save(pruned_model2.state_dict(), "/content/drive/MyDrive/hidden-networks/jeffrey_models/1e-4_100_50.pt")
# Out:
# Using device cuda
# Files already downloaded and verified
# Train Epoch: 1 [0/50000 (0%)]	Loss: 2.347297
# Train Epoch: 1 [12800/50000 (26%)]	Loss: 1.739054
# Train Epoch: 1 [25600/50000 (51%)]	Loss: 1.711622
# Train Epoch: 1 [38400/50000 (77%)]	Loss: 1.472040
#
# Test set: Average loss: 0.0014, Accuracy: 4838/10000 (48%)
#
# Train Epoch: 2 [0/50000 (0%)]	Loss: 1.493678
# Train Epoch: 2 [12800/50000 (26%)]	Loss: 1.377266
# Train Epoch: 2 [25600/50000 (51%)]	Loss: 1.457891
# Train Epoch: 2 [38400/50000 (77%)]	Loss: 1.450602
#
# Test set: Average loss: 0.0013, Accuracy: 5400/10000 (54%)
#
# Train Epoch: 3 [0/50000 (0%)]	Loss: 1.294692
# Train Epoch: 3 [12800/50000 (26%)]	Loss: 1.403667
# Train Epoch: 3 [25600/50000 (51%)]	Loss: 1.329526
# Train Epoch: 3 [38400/50000 (77%)]	Loss: 1.273843
#
# Test set: Average loss: 0.0011, Accuracy: 6029/10000 (60%)
#
# Train Epoch: 4 [0/50000 (0%)]	Loss: 1.290848
# Train Epoch: 4 [12800/50000 (26%)]	Loss: 1.169587
# ...

# %%
ortho_reg(pruned_model2.get_pruned_weights())
# Out:
# tensor(84.7306, device='cuda:0', grad_fn=<AddBackward0>)

# %%
num_layers = 2
sparsity = 0.5
layer_size = 7000

model_args = {
  "dataset": "CIFAR10",
  "batch_size": 128, # input batch size for training (default: 64)
  "epochs": 100, # number of epochs to train (default: 14)
  "lr": 0.1, # learning rate (default: 0.1)
  "momentum": 0.9, # Momentum (default: 0.9)
  'wd': 1e-4, # Weight decay (default: 0.0005)
  'no_cuda': False, # disables CUDA training
  'seed': 5, # random seed (default: 1)
  'save_name': None, # "simple20_rs2", # For Saving the current Model, None if not saving
  'sparsity': [sparsity] * 5, # 'how sparse is each layer'
  'copy_layers': [], # ['conv1', 'conv2', 'fc2'],
  'freeze_layers': [],
  'bias': False,
}

prune_args = {
    "test_batch_size": 1000, # input batch size for testing (default: 1000)
    'data': '../data', # Location to store data (e.g. MNIST)
    'log_interval': 100, # how many batches to wait before logging training status
    'train_eval_interval': None, # epoch interval at which to print training accuracy
    'test_eval_interval': 1, # epoch interval at which to print test accuracy
    'eval_train_on_last': False,
    'eval_test_on_last': True,
    'eval_on_last': True,
    'alpha': 1e-5,
    'reg': 'orth'
}

train_args = {
  "lr": 1e-4, # learning rate (default: 0.1)
  "momentum": 0.9, # Momentum (default: 0.9)
  'wd': 1e-3, # Weight decay (default: 0.0005)
  'epochs': 50,
  'log_interval': 100, # how many batches to wait before logging training status
  'train_eval_interval': None, # epoch interval at which to print training accuracy
  'test_eval_interval': 1, # epoch interval at which to print test accuracy
  'eval_train_on_last': False,
  'eval_test_on_last': True,
  'alpha': 0,
  'reg':'orth'
}



trained_model2, pruned_model2, device, train_loader, test_loader, criterion, prune_acc, prune_loss, train_acc, train_loss = prune_and_train(model_args, prune_args, train_args, cnn=True)
np.savetxt("/content/drive/MyDrive/hidden-networks/jeffrey_data/1e-5_2_prune_loss.csv", prune_loss, delimiter=",")
np.savetxt("/content/drive/MyDrive/hidden-networks/jeffrey_data/1e-5_2_prune_acc.csv", prune_acc, delimiter=",")
np.savetxt("/content/drive/MyDrive/hidden-networks/jeffrey_data/1e-5_2_train_loss.csv", train_loss, delimiter=",")
np.savetxt("/content/drive/MyDrive/hidden-networks/jeffrey_data/1e-5_2_train_acc.csv", train_acc, delimiter=",")
torch.save(trained_model2.state_dict(), "/content/drive/MyDrive/hidden-networks/jeffrey_models/1e-5_2.pt")
torch.save(pruned_model2.state_dict(), "/content/drive/MyDrive/hidden-networks/jeffrey_models/1e-5_2.pt")
# Out:
# Using device cuda
# Files already downloaded and verified
# Train Epoch: 1 [0/50000 (0%)]	Loss: 2.373432
# Train Epoch: 1 [12800/50000 (26%)]	Loss: 1.773232
# Train Epoch: 1 [25600/50000 (51%)]	Loss: 1.552279
# Train Epoch: 1 [38400/50000 (77%)]	Loss: 1.647041
#
# Test set: Average loss: 0.0014, Accuracy: 4848/10000 (48%)
#
# Train Epoch: 2 [0/50000 (0%)]	Loss: 1.599020
# Train Epoch: 2 [12800/50000 (26%)]	Loss: 1.632347
# Train Epoch: 2 [25600/50000 (51%)]	Loss: 1.193060
# Train Epoch: 2 [38400/50000 (77%)]	Loss: 1.391662
#
# Test set: Average loss: 0.0013, Accuracy: 5459/10000 (55%)
#
# Train Epoch: 3 [0/50000 (0%)]	Loss: 1.230691
# Train Epoch: 3 [12800/50000 (26%)]	Loss: 1.139582
# Train Epoch: 3 [25600/50000 (51%)]	Loss: 1.247871
# Train Epoch: 3 [38400/50000 (77%)]	Loss: 1.278183
#
# Test set: Average loss: 0.0012, Accuracy: 5814/10000 (58%)
#
# Train Epoch: 4 [0/50000 (0%)]	Loss: 1.481328
# Train Epoch: 4 [12800/50000 (26%)]	Loss: 1.124783
# ...

# %%
num_layers = 2
sparsity = 0.5
layer_size = 7000

model_args = {
  "dataset": "CIFAR10",
  "batch_size": 128, # input batch size for training (default: 64)
  "epochs": 100, # number of epochs to train (default: 14)
  "lr": 0.1, # learning rate (default: 0.1)
  "momentum": 0.9, # Momentum (default: 0.9)
  'wd': 1e-4, # Weight decay (default: 0.0005)
  'no_cuda': False, # disables CUDA training
  'seed': 5, # random seed (default: 1)
  'save_name': None, # "simple20_rs2", # For Saving the current Model, None if not saving
  'sparsity': [sparsity] * 5, # 'how sparse is each layer'
  'copy_layers': [], # ['conv1', 'conv2', 'fc2'],
  'freeze_layers': [],
  'bias': False,
}

prune_args = {
    "test_batch_size": 1000, # input batch size for testing (default: 1000)
    'data': '../data', # Location to store data (e.g. MNIST)
    'log_interval': 100, # how many batches to wait before logging training status
    'train_eval_interval': None, # epoch interval at which to print training accuracy
    'test_eval_interval': 1, # epoch interval at which to print test accuracy
    'eval_train_on_last': False,
    'eval_test_on_last': True,
    'eval_on_last': True,
    'alpha': 1e-5,
    'reg': 'orth'
}

train_args = {
  "lr": 1e-4, # learning rate (default: 0.1)
  "momentum": 0.9, # Momentum (default: 0.9)
  'wd': 1e-3, # Weight decay (default: 0.0005)
  'epochs': 50,
  'log_interval': 100, # how many batches to wait before logging training status
  'train_eval_interval': None, # epoch interval at which to print training accuracy
  'test_eval_interval': 1, # epoch interval at which to print test accuracy
  'eval_train_on_last': False,
  'eval_test_on_last': True,
  'alpha': 0,
  'reg':'orth'
}



trained_model2, pruned_model2, device, train_loader, test_loader, criterion, prune_acc, prune_loss, train_acc, train_loss = prune_and_train(model_args, prune_args, train_args, cnn=True)
np.savetxt("/content/drive/MyDrive/hidden-networks/jeffrey_data/1e-5_4_prune_loss.csv", prune_loss, delimiter=",")
np.savetxt("/content/drive/MyDrive/hidden-networks/jeffrey_data/1e-5_4_prune_acc.csv", prune_acc, delimiter=",")
np.savetxt("/content/drive/MyDrive/hidden-networks/jeffrey_data/1e-5_4_train_loss.csv", train_loss, delimiter=",")
np.savetxt("/content/drive/MyDrive/hidden-networks/jeffrey_data/1e-5_4_train_acc.csv", train_acc, delimiter=",")
torch.save(trained_model2.state_dict(), "/content/drive/MyDrive/hidden-networks/jeffrey_models/1e-5_4.pt")
torch.save(pruned_model2.state_dict(), "/content/drive/MyDrive/hidden-networks/jeffrey_models/1e-5_4.pt")
# Out:
# Using device cuda
# Files already downloaded and verified
# Train Epoch: 1 [0/50000 (0%)]	Loss: 2.373432
# Train Epoch: 1 [12800/50000 (26%)]	Loss: 1.775245
# Train Epoch: 1 [25600/50000 (51%)]	Loss: 1.562558
# Train Epoch: 1 [38400/50000 (77%)]	Loss: 1.653113
#
# Test set: Average loss: 0.0015, Accuracy: 4709/10000 (47%)
#
# Train Epoch: 2 [0/50000 (0%)]	Loss: 1.687375
# Train Epoch: 2 [12800/50000 (26%)]	Loss: 1.572842
# Train Epoch: 2 [25600/50000 (51%)]	Loss: 1.198553
# Train Epoch: 2 [38400/50000 (77%)]	Loss: 1.341897
#
# Test set: Average loss: 0.0013, Accuracy: 5440/10000 (54%)
#
# Train Epoch: 3 [0/50000 (0%)]	Loss: 1.235756
# Train Epoch: 3 [12800/50000 (26%)]	Loss: 1.189639
# Train Epoch: 3 [25600/50000 (51%)]	Loss: 1.266554
# Train Epoch: 3 [38400/50000 (77%)]	Loss: 1.256312
#
# Test set: Average loss: 0.0012, Accuracy: 5793/10000 (58%)
#
# Train Epoch: 4 [0/50000 (0%)]	Loss: 1.441821
# Train Epoch: 4 [12800/50000 (26%)]	Loss: 1.127102
# ...

# %%
# Arguments that do not affect model at all
num_layers = 2
sparsity = 0.5
layer_size = 7000

model_args = {
  "dataset": "CIFAR10",
  "batch_size": 128, # input batch size for training (default: 64)
  "epochs": 250, # number of epochs to train (default: 14)
  "lr": 0.1, # learning rate (default: 0.1)
  "momentum": 0.9, # Momentum (default: 0.9)
  'wd': 1e-4, # Weight decay (default: 0.0005)
  'no_cuda': False, # disables CUDA training
  'seed': 1, # random seed (default: 1)
  'save_name': None, # "simple20_rs2", # For Saving the current Model, None if not saving
  'sparsity': [sparsity] * 5, # 'how sparse is each layer'
  'copy_layers': [], # ['conv1', 'conv2', 'fc2'],
  'freeze_layers': [],
  'bias': False,
}

prune_args = {
    "test_batch_size": 1000, # input batch size for testing (default: 1000)
    'data': '../data', # Location to store data (e.g. MNIST)
    'log_interval': 100, # how many batches to wait before logging training status
    'train_eval_interval': None, # epoch interval at which to print training accuracy
    'test_eval_interval': 1, # epoch interval at which to print test accuracy
    'eval_train_on_last': False,
    'eval_test_on_last': True,
    'eval_on_last': True,
    'alpha': 1e-4,
    'reg': 'orth'
}

train_args = {
  "lr": 1e-4, # learning rate (default: 0.1)
  "momentum": 0.9, # Momentum (default: 0.9)
  'wd': 1e-3, # Weight decay (default: 0.0005)
  'epochs': 50,
  'log_interval': 100, # how many batches to wait before logging training status
  'train_eval_interval': None, # epoch interval at which to print training accuracy
  'test_eval_interval': 1, # epoch interval at which to print test accuracy
  'eval_train_on_last': False,
  'eval_test_on_last': True,
  'alpha': 0,
  'reg':'srip'
}



trained_model2, pruned_model2, device, train_loader, test_loader, criterion = prune_and_train(model_args, prune_args, train_args, cnn=True)
torch.save(trained_model2.state_dict(), "/content/drive/MyDrive/hidden-networks/jeffrey_models/trained_ortho1e-4_250_50")
torch.save(pruned_model2.state_dict(), "/content/drive/MyDrive/hidden-networks/jeffrey_models/prunedortho1e-4_250_50")
# Out:
# Using device cuda
# ...
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting ../data/CIFAR10/cifar-10-python.tar.gz to ../data/CIFAR10
# Train Epoch: 1 [0/50000 (0%)]	Loss: 2.365022
# Train Epoch: 1 [12800/50000 (26%)]	Loss: 1.897823
# Train Epoch: 1 [25600/50000 (51%)]	Loss: 1.604603
# Train Epoch: 1 [38400/50000 (77%)]	Loss: 1.461890
#
# Test set: Average loss: 0.0015, Accuracy: 4743/10000 (47%)
#
# Train Epoch: 2 [0/50000 (0%)]	Loss: 1.487518
# Train Epoch: 2 [12800/50000 (26%)]	Loss: 1.585291
# Train Epoch: 2 [25600/50000 (51%)]	Loss: 1.421389
# Train Epoch: 2 [38400/50000 (77%)]	Loss: 1.474057
#
# Test set: Average loss: 0.0014, Accuracy: 5139/10000 (51%)
#
# Train Epoch: 3 [0/50000 (0%)]	Loss: 1.397145
# Train Epoch: 3 [12800/50000 (26%)]	Loss: 1.545757
# Train Epoch: 3 [25600/50000 (51%)]	Loss: 1.370737
# Train Epoch: 3 [38400/50000 (77%)]	Loss: 1.446902
#
# Test set: Average loss: 0.0013, Accuracy: 5522/10000 (55%)
#
# Train Epoch: 4 [0/50000 (0%)]	Loss: 1.270178
# ...

# %%
f
